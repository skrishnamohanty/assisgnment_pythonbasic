# %% [raw]
# #1.Explain the key features of Python that make it a popular choice for programming?
# ans.1. Easy to Learn:
#     2. High-Level Language:
#     3. Versatile:
#     4. Large Standard Library:
#     5. Cross-Platform:
#     6. Dynamic Typing:
#     7. Object-Oriented:
#     8. Large Community:
#     9. Extensive Frameworks and Libraries:
#     10. Open-Source:

# %% [raw]
# #2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program

# %%
# predefined keywords are reserved words that have special meanings and are used to define the structure and logic of a program. These keywords are:

#numbers>>integer/float
#characters>>string in python
#true/false>>boolean
#none
print("hii")
# Out:
# hii

# %%
a=3
a
# Out:
# 3

# %%
type(a)
# Out:
# int

# %%
b=3.2
b
# Out:
# 3.2

# %%
type(b)
# Out:
# float

# %%
True or False
# Out:
# True

# %%
help('keyword')
# Out:
# Help on module keyword:
#
# NAME
#     keyword - Keywords (from "Grammar/python.gram")
#
# MODULE REFERENCE
#     https://docs.python.org/3.10/library/keyword.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     This file is automatically generated; please don't muck it up!
#
#     To update the symbols in this file, 'cd' to the top directory of
#     the python source tree and run:
#
#         PYTHONPATH=Tools/peg_generator python3 -m pegen.keywordgen         Grammar/python.gram         Grammar/Tokens         Lib/keyword.py
#
#     Alternatively, you can run 'make regen-keyword'.
#
# FUNCTIONS
#     iskeyword = __contains__(...) method of builtins.frozenset instance
# ...

# %%
if 3>2:
    print("grater")
# Out:
# grater

# %% [raw]
# #3. Compare and contrast mutable and immutable objects in Python with examples

# %%
#mutable object
#Can be changed after creation
#Modifications affect the original object
# Examples: lists, dictionaries, sets, user-defined classes

my_list=[1,2,3,4,5]
my_list.append(7)
my_list
# Out:
# [1, 2, 3, 4, 5, 7]

# %%
#immutable object
#Cannot be changed after creation
#Modifications create a new object
#Examples: integers, floats, strings, tuples

my_string = "hello"
my_string += "world"
print(my_string)#modification is possible.
# Out:
# helloworld

# %%
t=("bony","pw",1,2.3)#tuples
t
# Out:
# ('bony', 'pw', 1, 2.3)

# %%
type(t)
# Out:
# tuple

# %%
t[0]
# Out:
# 'bony'

# %%
t[0]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 t[0]=100
#
# TypeError: 'tuple' object does not support item assignment

# %% [raw]
# #4. Discuss the different types of operators in Python and provide examples of how they are used

# %%
#ANS.Python has several types of operators that perform various operations on variables and values. Here are the main categories and examples:
#ARITHMATICAL OPERATOR
a=40
b=20
a+b
# Out:
# 60

# %%
a-b
# Out:
# 20

# %%
a*b
# Out:
# 800

# %%
#modulous operator
21%4
# Out:
# 1

# %%
3**5
# Out:
# 243

# %%
#floor operator
4//3
# Out:
# 1

# %%
2==2
# Out:
# True

# %%
#logical operator
True-False
# Out:
# 1

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
#not operator
not False
# Out:
# True

# %%
#assignment operator
a=10
a
# Out:
# 10

# %%
a+56
# Out:
# 66

# %%
#membership operator
a=("bony")
"b" in a
# Out:
# True

# %%
"p" in a
# Out:
# False

# %%
#identity operator>> compares the location of the two object or variables
a=7
b=8
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
#bitwise operator
10&10
# Out:
# 10

# %%
bin (10)
# Out:
# '0b1010'

# %%
18&3
# Out:
# 2

# %%
bin (18)
# Out:
# '0b10010'

# %%
bin (3)
# Out:
# '0b11'

# %%
bin(2)
# Out:
# '0b10'

# %% [raw]
# #5. Explain the concept of type casting in Python with examples?

# %%
#Type casting in Python is the process of converting a variable's data type into another data type. This is done using built-in functions like int(), float(), str(), etc.

#Integer to Float
x = 10
y = float(x)
print(y)
# Out:
# 10.0

# %%
#Float to Integer
x = 10.5
y = int(x)
print(y)
# Out:
# 10

# %%
#String to Integer
x = "10"
y = int(x)
print(y)
# Out:
# 10

# %%
#Integer to String
x = 10
y = str(x)
print(y)
# Out:
# 10

# %%
#Float to String
x = 10.5
y = str(x)
print(y)
# Out:
# 10.5

# %%
#String to Float

x = "10.5"
y = float(x)
print(y)
# Out:
# 10.5

# %% [raw]
# #6.How do conditional statements work in Python? Illustrate with examples?

# %%
#conditional statement>>(IF,IFELSE,IFELIF,NESTEDIF)
#IF STATEMENT
a=100
if a>100:
    print("the number is greater than o")

# %%
a=100
if a>100:
    print("the number is greater than 0")

# %%
#if else
weather="rainy"
if weather=="rainy":
    print("i wiil paly cricket")
else:
    print("i will watch tv")
# Out:
# i wiil paly cricket

# %%
#ELIF
a=10
if a>100:
    print("a is greater than 100")
elif a<100:
        print("a is less thsn 100")
else:
    print("a is equal to 100")
# Out:
# a is less thsn 100

# %%
#NESTED IF>> we can have multiple if else inside itself
x=1
y=6
if x>5:
    if y>5:
        print("both  x and y is greater than 5")
else:
    print("x is greater than 5 but y is less than 5")
    else:
    print("x is not greater than 5")
# Out:
#   Cell In[96], line 9
#     else:
#     ^
# SyntaxError: invalid syntax

# %% [raw]
# #7.Describe the different types of loops in Python and their use cases with examples.

# %%
# there are mainly two type of loop
#while loop and for loop
#while loop>>repeatedly execute a block of code untill a codition is met
# for example
n=7
i=1
while i<n:
    print(i)
    i=i+1
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %%
#for loop>> iterate over a sequence of elements
# for example 
l=[1,2,"ajay","boni",2.3]
for i in l:
    print(i)
# Out:
# 1
# 2
# ajay
# boni
# 2.3
